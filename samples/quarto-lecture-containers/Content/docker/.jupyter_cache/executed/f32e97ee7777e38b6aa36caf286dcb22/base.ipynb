# %%
#| echo: false
#| output: false
export DOCKER_HOST=tcp://dind:2375

# %%
#| echo: true
#| output: true
docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
#| echo: true
#| output: true
docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
#| echo: true
#| output: true
docker images
# Out:
#                                                             i Info →   U  In Use
# IMAGE                ID             DISK USAGE   CONTENT SIZE   EXTRA
# hello-world:latest   ca9905c726f0        5.2kB             0B
# ubuntu:latest        9a84ec2d5dd7        101MB             0B

# %%
#| echo: true
#| output: true
docker images
# Out:
#                                                             i Info →   U  In Use
# IMAGE                ID             DISK USAGE   CONTENT SIZE   EXTRA
# hello-world:latest   ca9905c726f0        5.2kB             0B
# ubuntu:latest        9a84ec2d5dd7        101MB             0B

# %%
#| echo: true
#| output: true
docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED      STATUS      PORTS     NAMES
# 4f3370529d3f   ubuntu    "bash"    2 days ago   Up 2 days             nice_hofstadter

# %%
#| echo: true
#| output: true
docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND                  CREATED              STATUS                              PORTS     NAMES
# 5ec9b68a77a0   hello-world   "/hello"                 1 second ago         Exited (0) Less than a second ago             affectionate_faraday
# 33172951bf46   hello-world   "/hello"                 1 second ago         Exited (0) Less than a second ago             objective_kirch
# e9dac53d1da3   ubuntu        "echo 'Hello from Ub…"   About a minute ago   Exited (0) About a minute ago                 fervent_einstein
# be77e5f5df7e   ubuntu        "uname -a"               About a minute ago   Exited (0) About a minute ago                 serene_wright
# 120aa6220a63   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 beautiful_ride
# e5e1026365ac   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 jolly_jackson
# 2c8d0b52fda4   ubuntu        "echo 'Hello from Ub…"   About a minute ago   Exited (0) About a minute ago                 frosty_pare
# 20ad4da6bb71   ubuntu        "uname -a"               About a minute ago   Exited (0) About a minute ago                 condescending_hermann
# 57ec69331fc6   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 heuristic_visvesvaraya
# 6d08c268aa08   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 serene_northcutt
# 783a71598309   ubuntu        "bash"                   3 minutes ago        Exited (129) About a minute ago               focused_rubin
# bad5aecc0595   ubuntu        "uname -a"               3 minutes ago        Exited (0) 3 minutes ago                      funny_williams
# daa332fb7abf   hello-world   "/hello"                 3 minutes ago        Exited (0) 3 minutes ago                      elated_carson
# f5c55c988c78   hello-world   "/hello"                 3 minutes ago        Exited (0) 3 minutes ago                      ecstatic_shaw
# c9bc982e0f1a   ubuntu        "zsh"                    5 minutes ago        Created                                       jovial_raman
# dc994256ebb0   ubuntu        "uname -a"               5 minutes ago        Exited (0) 5 minutes ago                      gracious_borg
# 7a27cf51dbd6   hello-world   "/hello"                 5 minutes ago        Exited (0) 5 minutes ago                      agitated_brattain
# 0cb31a5612d0   hello-world   "/hello"                 5 minutes ago        Exited (0) 5 minutes ago                      silly_kare
# 2f35fb55c780   ubuntu        "zsh"                    3 hours ago          Created                                       objective_joliot
# 239668e8114e   ubuntu        "uname -a"               3 hours ago          Exited (0) 3 hours ago                        awesome_maxwell
# 7d2ff202f49f   hello-world   "/hello"                 3 hours ago          Exited (0) 3 hours ago                        blissful_liskov
# c73a68946f56   hello-world   "/hello"                 3 hours ago          Exited (0) 3 hours ago                        inspiring_visvesvaraya
# 4f3370529d3f   ubuntu        "bash"                   2 days ago           Up 2 days                                     nice_hofstadter
# c2e538b61d32   hello-world   "/hello"                 2 days ago           Exited (0) 2 days ago                         boring_allen

# %%
#| echo: true
#| output: true
docker ps       # containers actifs
docker ps -a    # tous les containers
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED      STATUS      PORTS     NAMES
# 4f3370529d3f   ubuntu    "bash"    2 days ago   Up 2 days             nice_hofstadter
# CONTAINER ID   IMAGE         COMMAND                  CREATED              STATUS                              PORTS     NAMES
# 5ec9b68a77a0   hello-world   "/hello"                 1 second ago         Exited (0) Less than a second ago             affectionate_faraday
# 33172951bf46   hello-world   "/hello"                 1 second ago         Exited (0) 1 second ago                       objective_kirch
# e9dac53d1da3   ubuntu        "echo 'Hello from Ub…"   About a minute ago   Exited (0) About a minute ago                 fervent_einstein
# be77e5f5df7e   ubuntu        "uname -a"               About a minute ago   Exited (0) About a minute ago                 serene_wright
# 120aa6220a63   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 beautiful_ride
# e5e1026365ac   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 jolly_jackson
# 2c8d0b52fda4   ubuntu        "echo 'Hello from Ub…"   About a minute ago   Exited (0) About a minute ago                 frosty_pare
# 20ad4da6bb71   ubuntu        "uname -a"               About a minute ago   Exited (0) About a minute ago                 condescending_hermann
# 57ec69331fc6   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 heuristic_visvesvaraya
# 6d08c268aa08   hello-world   "/hello"                 About a minute ago   Exited (0) About a minute ago                 serene_northcutt
# 783a71598309   ubuntu        "bash"                   3 minutes ago        Exited (129) About a minute ago               focused_rubin
# bad5aecc0595   ubuntu        "uname -a"               3 minutes ago        Exited (0) 3 minutes ago                      funny_williams
# daa332fb7abf   hello-world   "/hello"                 3 minutes ago        Exited (0) 3 minutes ago                      elated_carson
# f5c55c988c78   hello-world   "/hello"                 3 minutes ago        Exited (0) 3 minutes ago                      ecstatic_shaw
# c9bc982e0f1a   ubuntu        "zsh"                    5 minutes ago        Created                                       jovial_raman
# dc994256ebb0   ubuntu        "uname -a"               5 minutes ago        Exited (0) 5 minutes ago                      gracious_borg
# 7a27cf51dbd6   hello-world   "/hello"                 5 minutes ago        Exited (0) 5 minutes ago                      agitated_brattain
# 0cb31a5612d0   hello-world   "/hello"                 5 minutes ago        Exited (0) 5 minutes ago                      silly_kare
# 2f35fb55c780   ubuntu        "zsh"                    3 hours ago          Created                                       objective_joliot
# 239668e8114e   ubuntu        "uname -a"               3 hours ago          Exited (0) 3 hours ago                        awesome_maxwell
# 7d2ff202f49f   hello-world   "/hello"                 3 hours ago          Exited (0) 3 hours ago                        blissful_liskov
# c73a68946f56   hello-world   "/hello"                 3 hours ago          Exited (0) 3 hours ago                        inspiring_visvesvaraya
# 4f3370529d3f   ubuntu        "bash"                   2 days ago           Up 2 days                                     nice_hofstadter
# c2e538b61d32   hello-world   "/hello"                 2 days ago           Exited (0) 2 days ago                         boring_allen

# %%
#| echo: true
#| output: true
docker run ubuntu uname -a
# Out:
# Linux 2f3d35273328 6.8.0-64-generic #67-Ubuntu SMP PREEMPT_DYNAMIC Sun Jun 15 20:23:40 UTC 2025 aarch64 aarch64 aarch64 GNU/Linux

# %%
#| echo: true
#| output: true
docker run ubuntu echo "Hello from Ubuntu container"
# Out:
# Hello from Ubuntu container

# %%
#| echo: true
#| output: true
#| eval: false
docker container prune -f
