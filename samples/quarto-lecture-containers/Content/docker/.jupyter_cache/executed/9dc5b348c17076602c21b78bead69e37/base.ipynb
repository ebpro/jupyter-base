# %%
#| echo: false
#| output: false
export DOCKER_HOST=tcp://dind:2375
docker system prune --all --force
# Out:
# Total reclaimed space: 0B

# %%
#| echo: true
#| output: true
docker run hello-world
# Out:
# Unable to find image 'hello-world:latest' locally
# latest: Pulling from library/hello-world
# 198f93fd5094: Pulling fs layer
# 198f93fd5094: Downloading  1.369kB/3.021kB
# 198f93fd5094: Downloading  3.021kB/3.021kB
# 198f93fd5094: Verifying Checksum
# 198f93fd5094: Download complete
# 198f93fd5094: Extracting  3.021kB/3.021kB
# 198f93fd5094: Extracting  3.021kB/3.021kB
# 198f93fd5094: Pull complete
# Digest: sha256:d4aaab6242e0cace87e2ec17a2ed3d779d18fbfd03042ea58f2995626396a274
# Status: Downloaded newer image for hello-world:latest
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
#| echo: true
#| output: true
docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
#| echo: true
#| output: true
docker images
# Out:
#                                                             i Info →   U  In Use
# IMAGE                ID             DISK USAGE   CONTENT SIZE   EXTRA
# hello-world:latest   ca9905c726f0        5.2kB             0B
# ubuntu:latest        9a84ec2d5dd7        101MB             0B

# %%
#| echo: true
#| output: true
docker images
# Out:
#                                                             i Info →   U  In Use
# IMAGE                ID             DISK USAGE   CONTENT SIZE   EXTRA
# hello-world:latest   ca9905c726f0        5.2kB             0B
# ubuntu:latest        9a84ec2d5dd7        101MB             0B

# %%
#| echo: true
#| output: true
docker ps
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED      STATUS      PORTS     NAMES
# 4f3370529d3f   ubuntu    "bash"    3 days ago   Up 3 days             nice_hofstadter

# %%
#| echo: true
#| output: true
docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED        STATUS                              PORTS     NAMES
# 1183354410d1   hello-world   "/hello"   1 second ago   Exited (0) Less than a second ago             clever_ride
# 7e2a2310bfb5   hello-world   "/hello"   1 second ago   Exited (0) Less than a second ago             eloquent_tu
# 4f3370529d3f   ubuntu        "bash"     3 days ago     Up 3 days                                     nice_hofstadter

# %%
#| echo: true
#| output: true
docker ps       # containers actifs
docker ps -a    # tous les containers
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED      STATUS      PORTS     NAMES
# 4f3370529d3f   ubuntu    "bash"    3 days ago   Up 3 days             nice_hofstadter
# CONTAINER ID   IMAGE         COMMAND    CREATED        STATUS                              PORTS     NAMES
# 1183354410d1   hello-world   "/hello"   1 second ago   Exited (0) Less than a second ago             clever_ride
# 7e2a2310bfb5   hello-world   "/hello"   1 second ago   Exited (0) 1 second ago                       eloquent_tu
# 4f3370529d3f   ubuntu        "bash"     3 days ago     Up 3 days                                     nice_hofstadter

# %%
#| echo: true
#| output: true
docker run ubuntu uname -a
# Out:
# Linux d98b70e77a35 6.8.0-64-generic #67-Ubuntu SMP PREEMPT_DYNAMIC Sun Jun 15 20:23:40 UTC 2025 aarch64 aarch64 aarch64 GNU/Linux

# %%
#| echo: true
#| output: true
docker run ubuntu echo "Hello from Ubuntu container"
# Out:
# Hello from Ubuntu container

# %%
#| echo: true
#| output: true
#| eval: false
docker container prune -f
