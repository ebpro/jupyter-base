// %%
int age = 20;
if (age >= 18) {
  System.out.println("Majeur");
} else {
  System.out.println("Mineur");
}
// Out:
// Majeur

// %%
// Expected output:
// Majeur

// Example function-style snippet:
int checkAge(int age) {
  if (age >= 18) return 1; // 1 => Majeur
  else return 0; // 0 => Mineur
}
System.out.println(checkAge(20) == 1 ? "Majeur" : "Mineur");
// Out:
// Majeur

// %%
// Write your implementation here

// %%
int sumArray(int[] arr) {
  int s = 0;
  for (int v : arr) s += v;
  return s;
}

int[] arr = {10, 20, 30};
System.out.println("Sum: " + sumArray(arr));
// Expected output: Sum: 60
// Out:
// Sum: 60
